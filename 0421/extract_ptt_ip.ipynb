# %%
from pathlib import Path

import requests
import pandas as pd
from bs4 import BeautifulSoup

from crawler_utilities import extract_article_op_IP

# %%
# 設定儲存文章的資料夾路徑
FOLDER_PATH = Path("./ptt_articles_op_IP")
# 建立資料夾（若不存在則自動建立）
FOLDER_PATH.mkdir(parents=True, exist_ok=True)

# %%
url = 'https://www.ptt.cc/bbs/Gossiping/index.html'

headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/135.0.0.0 Safari/537.36'
}

cookies = {"over18": "1"}

# %%
ip_country = []
for _ in range(2):
    # 發送 GET 請求取得網頁內容
    res = requests.get(url, headers=headers, cookies=cookies)
    soup = BeautifulSoup(res.text, "html.parser")

    # 取得所有文章標題區塊
    title_tag_list = soup.select('div[class="title"]')

    for tag in title_tag_list:
        # 取得標題連結標籤
        title_a_tag = tag.select_one("a")
        # 取得標題文字
        title = title_a_tag.text if title_a_tag else "No Title"
        # 取得文章網址
        article_url = "https://www.ptt.cc" + title_a_tag["href"] if title_a_tag else "No URL"

        print(f"Title: {title}")
        print(f"URL: {article_url}")
        
        # 若無法取得網址則跳過
        if "No URL" in article_url:
            print("No URL found, skipping...")
            print()
            continue

        # 擷取文章OP的IP
        result = extract_article_op_IP(article_url, headers, cookies)
        if result:
            print(result)
            print()
            ip_country.append(result)
        else:
            continue

    # 取得「上頁」按鈕，更新 url 以便爬取上一頁
    for btn_tag in soup.select('a[class="btn wide"]'):
        if "上頁" in btn_tag.text:
            url = "https://www.ptt.cc" + btn_tag["href"]
            break
    else:
        # 若找不到「上頁」按鈕則結束爬蟲
        print("No previous page found.")
        break
    print("=====================================")
# Out:
# Title: [問卦] 現在讀餐飲系的在幹嘛?
# URL: https://www.ptt.cc/bbs/Gossiping/M.1745247891.A.365.html
# ['118.160.47.8', '臺灣']
#
# Title: [問卦] 今年還有哪個龍頭會啪一聲沒了？
# URL: https://www.ptt.cc/bbs/Gossiping/M.1745247916.A.D62.html
# ['101.12.144.110', '臺灣']
#
# Title: Re: [爆卦] 李顯龍妻子fb轉嗆習近平是黑幫老大的文章
# URL: https://www.ptt.cc/bbs/Gossiping/M.1745247932.A.940.html
# ['114.34.108.96', '臺灣']
#
# Title: [新聞] 預算凍刪導致外交部發不出護照？　招標
# URL: https://www.ptt.cc/bbs/Gossiping/M.1745248028.A.0CD.html
# ['42.72.127.126', '臺灣']
#
# Title: [問卦] 為什麼上帝可以變黑人  白雪公主不行?
# URL: https://www.ptt.cc/bbs/Gossiping/M.1745248041.A.DFC.html
# ['123.194.132.183', '臺灣']
#
# Title: Re: [問卦] 楊舒雅嗆：鍵盤酸民直接來我的演講talk
# URL: https://www.ptt.cc/bbs/Gossiping/M.1745248099.A.1AB.html
# ['50.53.5.43', '美國']
#
# Title: [問卦] 為什麼新竹這麼多看板啊
# URL: https://www.ptt.cc/bbs/Gossiping/M.1745248289.A.A1C.html
# ['111.251.194.165', '臺灣']
#
# Title: [公告] 八卦板板規(2025.01.21)
# URL: https://www.ptt.cc/bbs/Gossiping/M.1737398137.A.644.html
# ['118.165.88.146', '臺灣']
#
# Title: Fw: [公告] 請避免與登入1次之帳號進行交易 發錢
# URL: https://www.ptt.cc/bbs/Gossiping/M.1741791500.A.EB6.html
# ['220.135.133.179', '臺灣']
#
# Title: [公告] 壹蘋未確實查證警告，禁發記者魏盈盈新聞
# URL: https://www.ptt.cc/bbs/Gossiping/M.1743920492.A.0DB.html
# ['59.120.192.119', '臺灣']
#
# Title: [協尋] 4/17高師大20.00警察亂抓人
# URL: https://www.ptt.cc/bbs/Gossiping/M.1744941348.A.789.html
# ['36.239.34.74', '臺灣']
#
# =====================================
# Title: Re: [問卦] 美國是不是不行了？
# URL: https://www.ptt.cc/bbs/Gossiping/M.1745246848.A.6D7.html
# ['99.43.254.103', '美國']
#
# Title: [問卦] 最近兩三次看見這種蟲 是啥
# URL: https://www.ptt.cc/bbs/Gossiping/M.1745246892.A.8EC.html
# ['36.239.99.180', '臺灣']
#
# Title: [新聞] 南韓FA-50戰機真香!埃及想買100架強化空
# URL: https://www.ptt.cc/bbs/Gossiping/M.1745246956.A.24F.html
# ['118.166.143.231', '臺灣']
#
# Title: [新聞] 川普連番批鮑爾 引爆美元信心危機
# URL: https://www.ptt.cc/bbs/Gossiping/M.1745246983.A.7FE.html
# ['114.40.74.148', '臺灣']
#
# Title: [問卦] 有沒有PTT登入次數 影響顏色的八卦?
# URL: https://www.ptt.cc/bbs/Gossiping/M.1745246991.A.22E.html
# ['218.173.0.182', '臺灣']
#
# Title: [問卦] 角頭宇宙還能拍幾集
# URL: https://www.ptt.cc/bbs/Gossiping/M.1745247031.A.73F.html
# No match found
# Title: [問卦] 有沒有第一次去健身房AirPods就被人拿走
# URL: https://www.ptt.cc/bbs/Gossiping/M.1745247043.A.A25.html
# ['223.139.87.125', '臺灣']
#
# Title: [新聞] 顛覆認知！大型研究揭未婚者失智風險低
# URL: https://www.ptt.cc/bbs/Gossiping/M.1745247243.A.CD7.html
# ['223.137.186.115', '臺灣']
#
# Title: [問卦] 清德宗任內有很多共諜嗎？
# URL: https://www.ptt.cc/bbs/Gossiping/M.1745247264.A.9FC.html
# ['149.22.84.167', '美國']
#
# Title: [問卦] 輝達和特斯拉又打折了？
# URL: https://www.ptt.cc/bbs/Gossiping/M.1745247283.A.1FB.html
# ['36.234.71.73', '臺灣']
#
# Title: [問卦] 咖啡豆為何不自己烘
# URL: https://www.ptt.cc/bbs/Gossiping/M.1745247373.A.1FC.html
# ['1.34.243.138', '臺灣']
#
# Title: [問卦] 問一部黑道賭博吃紅的片
# URL: https://www.ptt.cc/bbs/Gossiping/M.1745247421.A.6A9.html
# ['111.248.229.82', '臺灣']
#
# Title: Re: [新聞] 今年十月後護照存量吃緊　外交部：預算遭
# URL: https://www.ptt.cc/bbs/Gossiping/M.1745247576.A.928.html
# ['42.79.2.219', '臺灣']
#
# Title: Re: [新聞] 控羅智強陳情找嘸人 苗博雅:由我守護大安
# URL: https://www.ptt.cc/bbs/Gossiping/M.1745247579.A.454.html
# ['220.135.102.91', '臺灣']
#
# Title: [新聞] 北理工46歲副院長出軌24歲男生 細節曝光
# URL: https://www.ptt.cc/bbs/Gossiping/M.1745247635.A.14E.html
# ['180.177.10.15', '臺灣']
#
# Title: [問卦] Kindle支持博客來的電子書格式嗎?
# URL: https://www.ptt.cc/bbs/Gossiping/M.1745247664.A.E28.html
# ['203.56.147.237', '澳大利亞']
#
# Title: [問卦] 什麼人還在用雅虎拍賣
# URL: https://www.ptt.cc/bbs/Gossiping/M.1745247680.A.8FB.html
# ['114.44.18.218', '臺灣']
#
# Title: [新聞] 紐西蘭牛乳1公升38元「零關稅來台」賣96
# URL: https://www.ptt.cc/bbs/Gossiping/M.1745247773.A.44B.html
# ['114.36.34.118', '臺灣']
#
# Title: Re: [問卦] 宋朝被蠻族虐菜的原因是不是文組治國
# URL: https://www.ptt.cc/bbs/Gossiping/M.1745247859.A.614.html
# ['114.34.211.235', '臺灣']
#
# Title: [問卦] 同人展 跟 動漫展 差別在哪？
# URL: https://www.ptt.cc/bbs/Gossiping/M.1745247883.A.9AF.html
# ['49.216.177.169', '臺灣']
#
# =====================================

# %%
columns = ['IP地址', '國家']
df = pd.DataFrame(data=ip_country, columns=columns)
df
# Out:
#                IP地址    國家
# 0      118.160.47.8    臺灣
# 1    101.12.144.110    臺灣
# 2     114.34.108.96    臺灣
# 3     42.72.127.126    臺灣
# 4   123.194.132.183    臺灣
# 5        50.53.5.43    美國
# 6   111.251.194.165    臺灣
# 7    118.165.88.146    臺灣
# 8   220.135.133.179    臺灣
# 9    59.120.192.119    臺灣
# 10     36.239.34.74    臺灣
# 11    99.43.254.103    美國
# 12    36.239.99.180    臺灣
# 13  118.166.143.231    臺灣
# 14    114.40.74.148    臺灣
# 15    218.173.0.182    臺灣
# 16   223.139.87.125    臺灣
# 17  223.137.186.115    臺灣
# 18    149.22.84.167    美國
# 19     36.234.71.73    臺灣
# 20     1.34.243.138    臺灣
# 21   111.248.229.82    臺灣
# 22      42.79.2.219    臺灣
# 23   220.135.102.91    臺灣
# 24    180.177.10.15    臺灣
# 25   203.56.147.237  澳大利亞
# 26    114.44.18.218    臺灣
# 27    114.36.34.118    臺灣
# 28   114.34.211.235    臺灣
# 29   49.216.177.169    臺灣

# %%
df.to_csv(r'./ptt_articles_op_ip/pttGossiping.csv', index=False, encoding='utf-8-sig')
