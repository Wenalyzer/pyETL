# %%
import requests
from bs4 import BeautifulSoup

url = "https://organic.afa.gov.tw/InOrganic/QueryApplyList"

headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/135.0.0.0 Safari/537.36"
}
    
data = {
    "TYPE": "1",
    "YEAR": "111",
    "qNnify_NO": "",
    "qC_NAME": "",
    "qPaper_NO": "",
    "qProduct_NAME": "米".encode("big5"),
    "B": "查　　詢"
}

# %%
res = requests.post(url, headers=headers, data=data)
res
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(res.text, "html.parser")
# Out:
# <html>
#  <head>
#   <title>
#   </title>
#   <meta content="Microsoft FrontPage 5.0" name="GENERATOR"/>
#   <meta content="no-cache" http-equiv="pragma"/>
#   <meta content="0" http-equiv="expires"/>
#   <meta content="no-cache" http-equiv="cache-control"/>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <style type="text/css">
#    <!--
# body {
# 	margin-left: 18px;
# 	margin-top: 0px;
# 	margin-right: 0px;
# 	margin-bottom: 0px;
# }
# -->
#   </style>
#   <link href="style3.css" rel="stylesheet" type="text/css"/>
#   <link href="nn.css" rel="stylesheet" type="text/css"/>
#   <script type="text/javascript">
#    var strProtocol = location.protocol;
# 	//alert('Protocol='+strProtocol);
# 　if ( strProtocol== 'http:' ){
# 	    //location.href="https://organic.afa.gov.tw/InOrganic";
#   }
#   </script>
#   <script language="JavaScript">
#    function CheckData(form){
# 	  if(document.form.YEAR.value=="" && document.form.qNnify_NO.value=="" &&
# 	      document.form.qC_NAME.value=="" && document.form.qPaper_NO.value=="" &&
# 		  document.form.qProduct_NAME.value==""){
# 			  alert("請輸入查詢條件！");
# 			  return false;
# 	  }
# 	  if(document.form.YEAR.value != ""){
# 		  if(document.form.qNnify_NO.value=="" &&
# 			  document.form.qC_NAME.value=="" && document.form.qPaper_NO.value=="" &&
# 			  document.form.qProduct_NAME.value==""){
# 				  alert("查詢條件如選擇年度時，必須至少再加其他條件之一！");
# 				  return false;
# 		  }
# 	  }
#
#   }
#   </script>
#  </head>
#  <body class="txt1" leftmargin="0" marginheight="0" marginwidth="0" topmargin="0">
#   <form action="QueryApplyList" method="post" name="form" onsubmit="return(CheckData(this))">
#    <p>
#     <table border="0" cellpadding="0" cellspacing="0" width="801">
#      <tr>
#       <td align="center" valign="top" width="781">
#        <table align="center" border="1" bordercolordark="#333333" bordercolorlight="#333333" cellpadding="0" cellspacing="0" width="781">
#         <tr>
#          <td align="center" class="A02" colspan="3">
#           已核發同意文件查詢(
#           <font color="#FF0000">
#            農產品
#           </font>
#           )
#           <br/>
#           <input name="TYPE" type="hidden" value="1"/>
#           <br/>
#           <table align="center" border="0" bordercolordark="#333333" bordercolorlight="#333333" cellpadding="0" cellspacing="0" width="100%">
#            <tr>
#             <td width="3%">
#             </td>
#             <td width="16%">
#              年度：
#             </td>
#             <td colspan="2">
#              <select name="YEAR">
#               <option value="">
#                請選擇年度
#               </option>
#               <option value="98">
#                98
#               </option>
#               <option value="99">
#                99
#               </option>
#               <option value="100">
#                100
#               </option>
#               <option value="101">
#                101
#               </option>
#               <option value="102">
#                102
#               </option>
#               <option value="103">
#                103
#               </option>
#               <option value="104">
#                104
#               </option>
#               <option value="105">
#                105
#               </option>
#               <option value="106">
#                106
#               </option>
#               <option value="107">
#                107
#               </option>
#               <option value="108">
#                108
#               </option>
#               <option value="109">
#                109
#               </option>
#               <option value="110">
#                110
#               </option>
#               <option selected="" value="111">
#                111
#               </option>
#               <option value="112">
#                112
#               </option>
#               <option value="113">
#                113
#               </option>
#               <option value="114">
#                114
#               </option>
#              </select>
#             </td>
#            </tr>
#            <tr>
#             <td width="3%">
#             </td>
#             <td width="16%">
#              統一編號：
#             </td>
#             <td colspan="2">
#              <input name="qNnify_NO" type="text" value=""/>
#             </td>
#            </tr>
#            <tr>
#             <td width="3%">
#             </td>
#             <td width="16%">
#              廠商名稱：
#             </td>
#             <td colspan="2">
#              <input name="qC_NAME" type="text" value=""/>
#             </td>
#            </tr>
#            <tr>
#             <td width="3%">
#             </td>
#             <td width="16%">
#              同意文件字號：
#             </td>
#             <td colspan="2">
#              <input name="qPaper_NO" type="text" value=""/>
#             </td>
#            </tr>
#            <tr>
#             <td width="3%">
#             </td>
#             <td width="16%">
#              產品名稱：
#             </td>
#             <td width="22%">
#              <input name="qProduct_NAME" type="text" value="米"/>
#             </td>
#             <td width="59%">
#              <input class="input1" name="B" type="submit" value="查　　詢"/>
#             </td>
#            </tr>
#           </table>
#          </td>
#         </tr>
#         <tr>
#          <td align="center" width="355">
#           廠商名稱
#          </td>
#          <td align="center" width="197">
#           聯絡電話
#          </td>
#          <td align="center" width="211">
#           核發案件編號
#          </td>
#         </tr>
#         <tr>
#          <td>
#           統一生機開發股份有限公司
#          </td>
#          <td align="left">
#           03-4340372
#          </td>
#          <td align="center">
#           <a href="QueryApplyDetail?Case_NO=120221034002&amp;Nnify_NO=16781797">
#            AGGR-111-1034-002
#           </a>
#          </td>
#         </tr>
#         <tr>
#          <td>
#           統一生機開發股份有限公司
#          </td>
#          <td align="left">
#           03-4340372
#          </td>
#          <td align="center">
#           <a href="QueryApplyDetail?Case_NO=120221034008&amp;Nnify_NO=16781797">
#            AGGR-111-1034-008
#           </a>
#          </td>
#         </tr>
#         <tr>
#          <td>
#           統一生機開發股份有限公司
#          </td>
#          <td align="left">
#           03-4340372
#          </td>
#          <td align="center">
#           <a href="QueryApplyDetail?Case_NO=120221034009&amp;Nnify_NO=16781797">
#            AGGR-111-1034-009
#           </a>
#          </td>
#         </tr>
#         <tr>
#          <td>
#           統一生機開發股份有限公司
#          </td>
#          <td align="left">
#           03-4340372
#          </td>
#          <td align="center">
#           <a href="QueryApplyDetail?Case_NO=120221034018&amp;Nnify_NO=16781797">
#            AGGR-111-1034-018
#           </a>
#          </td>
#         </tr>
#         <tr>
#          <td>
#           青荷國際有限公司
#          </td>
#          <td align="left">
#           03-3594557
#          </td>
#          <td align="center">
#           <a href="QueryApplyDetail?Case_NO=120221067003&amp;Nnify_NO=24407269">
#            AGGR-111-1067-003
#           </a>
#          </td>
#         </tr>
#         <tr>
#          <td>
#           青荷國際有限公司
#          </td>
#          <td align="left">
#           03-3594557
#          </td>
#          <td align="center">
#           <a href="QueryApplyDetail?Case_NO=120221067006&amp;Nnify_NO=24407269">
#            AGGR-111-1067-006
#           </a>
#          </td>
#         </tr>
#         <tr>
#          <td>
#           青荷國際有限公司
#          </td>
#          <td align="left">
#           03-3594557
#          </td>
#          <td align="center">
#           <a href="QueryApplyDetail?Case_NO=120221067020&amp;Nnify_NO=24407269">
#            AGGR-111-1067-020
#           </a>
#          </td>
#         </tr>
#         <tr>
#          <td>
#           青荷國際有限公司
#          </td>
#          <td align="left">
#           03-3594557
#          </td>
#          <td align="center">
#           <a href="QueryApplyDetail?Case_NO=120221067021&amp;Nnify_NO=24407269">
#            AGGR-111-1067-021
#           </a>
#          </td>
#         </tr>
#         <tr>
#          <td>
#           青荷國際有限公司
#          </td>
#          <td align="left">
#           03-3594557
#          </td>
#          <td align="center">
#           <a href="QueryApplyDetail?Case_NO=120221067033&amp;Nnify_NO=24407269">
#            AGGR-111-1067-033
#           </a>
#          </td>
#         </tr>
#         <tr>
#          <td>
#           綠動會股份有限公司
#          </td>
#          <td align="left">
#           04-25299885
#          </td>
#          <td align="center">
#           <a href="QueryApplyDetail?Case_NO=220222003605&amp;Nnify_NO=24430183">
#            AGGR-111-2003-605
#           </a>
#          </td>
#         </tr>
#         <tr>
#          <td>
#           新和食品股份有限公司
#          </td>
#          <td align="left">
#           02-25954321
#          </td>
#          <td align="center">
#           <a href="QueryApplyDetail?Case_NO=120221649006&amp;Nnify_NO=24956270">
#            AGGR-111-1649-006
#           </a>
#          </td>
#         </tr>
#         <tr>
#          <td>
#           綠昇貿易行銷有限公司
#          </td>
#          <td align="left">
#           04-26262377
#          </td>
#          <td align="center">
#           <a href="QueryApplyDetail?Case_NO=220222004016&amp;Nnify_NO=25054571">
#            AGGR-111-2004-016
#           </a>
#          </td>
#         </tr>
#         <tr>
#          <td>
#           日商沖繩伊藤園股份有限公司台灣分公司
#          </td>
#          <td align="left">
#           0225163123
#          </td>
#          <td align="center">
#           <a href="QueryApplyDetail?Case_NO=1202211089001&amp;Nnify_NO=53652917">
#            AGGR-111-1A89-001
#           </a>
#          </td>
#         </tr>
#         <tr>
#          <td>
#           智慧體股份有限公司
#          </td>
#          <td align="left">
#           27670988
#          </td>
#          <td align="center">
#           <a href="QueryApplyDetail?Case_NO=120221311002&amp;Nnify_NO=54150883">
#            AGGR-111-1311-002
#           </a>
#          </td>
#         </tr>
#         <tr>
#          <td>
#           智慧體股份有限公司
#          </td>
#          <td align="left">
#           27670988
#          </td>
#          <td align="center">
#           <a href="QueryApplyDetail?Case_NO=120221311004&amp;Nnify_NO=54150883">
#            AGGR-111-1311-004
#           </a>
#          </td>
#         </tr>
#         <tr>
#          <td>
#           日商夢多貿易股份有限公司台灣分公司
#          </td>
#          <td align="left">
#           0227200322
#          </td>
#          <td align="center">
#           <a href="QueryApplyDetail?Case_NO=1202211040001&amp;Nnify_NO=54952841">
#            AGGR-111-1A40-001
#           </a>
#          </td>
#         </tr>
#         <tr>
#          <td>
#           苗林食品有限公司
#          </td>
#          <td align="left">
#           02-2581-0034
#          </td>
#          <td align="center">
#           <a href="QueryApplyDetail?Case_NO=120221046001&amp;Nnify_NO=84754875">
#            AGGR-111-1046-001
#           </a>
#          </td>
#         </tr>
#         <tr>
#          <td>
#           好市多股份有限公司
#          </td>
#          <td align="left">
#           02-87919988
#          </td>
#          <td align="center">
#           <a href="QueryApplyDetail?Case_NO=320223309002&amp;Nnify_NO=96972798">
#            AGGR-111-3309-002
#           </a>
#          </td>
#         </tr>
#         <tr>
#          <td>
#           好市多股份有限公司
#          </td>
#          <td align="left">
#           02-87919988
#          </td>
#          <td align="center">
#           <a href="QueryApplyDetail?Case_NO=320223309003&amp;Nnify_NO=96972798">
#            AGGR-111-3309-003
#           </a>
#          </td>
#         </tr>
#         <tr>
#          <td>
#           好市多股份有限公司
#          </td>
#          <td align="left">
#           02-87919988
#          </td>
#          <td align="center">
#           <a href="QueryApplyDetail?Case_NO=320223309010&amp;Nnify_NO=96972798">
#            AGGR-111-3309-010
#           </a>
#          </td>
#         </tr>
#         <tr>
#          <td>
#           好市多股份有限公司
#          </td>
#          <td align="left">
#           02-87919988
#          </td>
#          <td align="center">
#           <a href="QueryApplyDetail?Case_NO=320223309015&amp;Nnify_NO=96972798">
#            AGGR-111-3309-015
#           </a>
#          </td>
#         </tr>
#         <tr>
#          <td>
#           好市多股份有限公司
#          </td>
#          <td align="left">
#           02-87919988
#          </td>
#          <td align="center">
#           <a href="QueryApplyDetail?Case_NO=320223309052&amp;Nnify_NO=96972798">
#            AGGR-111-3309-052
#           </a>
#          </td>
#         </tr>
#         <tr>
#          <td>
#           好市多股份有限公司
#          </td>
#          <td align="left">
#           02-87919988
#          </td>
#          <td align="center">
#           <a href="QueryApplyDetail?Case_NO=320223309069&amp;Nnify_NO=96972798">
#            AGGR-111-3309-069
#           </a>
#          </td>
#         </tr>
#         <tr>
#          <td>
#           好市多股份有限公司
#          </td>
#          <td align="left">
#           02-87919988
#          </td>
#          <td align="center">
#           <a href="QueryApplyDetail?Case_NO=320223309070&amp;Nnify_NO=96972798">
#            AGGR-111-3309-070
#           </a>
#          </td>
#         </tr>
#         <tr>
#          <td>
#           好市多股份有限公司
#          </td>
#          <td align="left">
#           02-87919988
#          </td>
#          <td align="center">
#           <a href="QueryApplyDetail?Case_NO=320223309133&amp;Nnify_NO=96972798">
#            AGGR-111-3309-133
#           </a>
#          </td>
#         </tr>
#        </table>
#       </td>
#      </tr>
#     </table>
#    </p>
#   </form>
#  </body>
# </html>

# %%
soup.select('input')
# Out:
# [<input name="TYPE" type="hidden" value="1"/>,
#  <input name="qNnify_NO" type="text" value=""/>,
#  <input name="qC_NAME" type="text" value=""/>,
#  <input name="qPaper_NO" type="text" value=""/>,
#  <input name="qProduct_NAME" type="text" value="米"/>,
#  <input class="input1" name="B" type="submit" value="查　　詢"/>]

# %%
print(res.text)
# Out:
# <html>
# <head>
# <title></title>
# <meta name="GENERATOR" content="Microsoft FrontPage 5.0">
# <meta http-equiv="pragma" content="no-cache">
# <meta http-equiv="expires" content="0">
# <meta http-equiv="cache-control" content="no-cache">
# <meta http-equiv="Content-Type" content="text/html; charset=Big5">
# <style type="text/css">
# <!--
# body {
# 	margin-left: 18px;
# 	margin-top: 0px;
# 	margin-right: 0px;
# 	margin-bottom: 0px;
# }
# -->
# </style>
# <LINK href="style3.css" rel="stylesheet" type="text/css">
# <LINK href="nn.css" rel="stylesheet" type="text/css">
# <script type="text/javascript">
# 	var strProtocol = location.protocol;
# 	//alert('Protocol='+strProtocol);
# 　if ( strProtocol== 'http:' ){
# 	    //location.href="https://organic.afa.gov.tw/InOrganic";
#   }
# </script>
# <script LANGUAGE="JavaScript">
#   function CheckData(form){
# 	  if(document.form.YEAR.value=="" && document.form.qNnify_NO.value=="" &&
# 	      document.form.qC_NAME.value=="" && document.form.qPaper_NO.value=="" &&
# 		  document.form.qProduct_NAME.value==""){
# 			  alert("請輸入查詢條件！");
# 			  return false;
# 	  }
# 	  if(document.form.YEAR.value != ""){
# 		  if(document.form.qNnify_NO.value=="" &&
# 			  document.form.qC_NAME.value=="" && document.form.qPaper_NO.value=="" &&
# 			  document.form.qProduct_NAME.value==""){
# 				  alert("查詢條件如選擇年度時，必須至少再加其他條件之一！");
# 				  return false;
# 		  }
# 	  }
#
#   }
# </Script>
# </head>
# <BODY class=txt1 leftmargin="0" topmargin="0" marginwidth="0" marginheight="0">
# <form name="form" action="QueryApplyList" method="post" onSubmit="return(CheckData(this))">
# <P>
#   <TABLE width="801" border="0" cellspacing="0" cellpadding="0" >
#     <TR>
#       <TD width="781" valign="top" align="center">
#       <TABLE width="781" border="1" cellspacing="0" cellpadding="0" align="center" bordercolorlight="#333333" bordercolordark="#333333">
#           <TR>
#             <TD colspan="3"  align="center" class="A02">已核發同意文件查詢(<font color="#FF0000">農產品</font>)<BR>
#
# 			  <input type="hidden" NAME="TYPE" value="1">
#               <BR>
#               <TABLE border="0" cellspacing="0" cellpadding="0" align="center" bordercolorlight="#333333" bordercolordark="#333333" width="100%">
#                 <TR>
#                   <TD width="3%">&nbsp;</TD>
#                   <TD width="16%">年度：</TD>
#                   <TD colspan="2">
#                       <select name="YEAR">
#                           <option value="">請選擇年度</option>
#
#                           <option value="98" >98</option>
#
#                           <option value="99" >99</option>
#
#                           <option value="100" >100</option>
#
#                           <option value="101" >101</option>
#
#                           <option value="102" >102</option>
#
#                           <option value="103" >103</option>
#
#                           <option value="104" >104</option>
#
#                           <option value="105" >105</option>
#
#                           <option value="106" >106</option>
#
#                           <option value="107" >107</option>
#
#                           <option value="108" >108</option>
#
#                           <option value="109" >109</option>
#
#                           <option value="110" >110</option>
#
#                           <option value="111" SELECTED>111</option>
#
#                           <option value="112" >112</option>
#
#                           <option value="113" >113</option>
#
#                           <option value="114" >114</option>
#
#                       </select>
#                   </TD>
#                 </TR>
#                 <TR>
#                   <TD width="3%">&nbsp;</TD>
#                   <TD width="16%">統一編號：</TD>
#                   <TD colspan="2">
#                       <input type="text" name="qNnify_NO" value="">
#                   </TD>
#                 </TR>
#                 <TR>
#                   <TD width="3%">&nbsp;</TD>
#                   <TD width="16%">廠商名稱：</TD>
#                   <TD colspan="2">
#                       <input type="text" name="qC_NAME" value="">
#                   </TD>
#                 </TR>
#                 <TR>
#                   <TD width="3%">&nbsp;</TD>
#                   <TD width="16%">同意文件字號：</TD>
#                   <TD colspan="2">
#                       <input type="text" name="qPaper_NO" value="">
#                   </TD>
#                 </TR>
#                 <TR>
#                   <TD width="3%">&nbsp;</TD>
#                   <TD width="16%">產品名稱：</TD>
#                   <TD width="22%">
#                       <input type="text" name="qProduct_NAME" value="米">
#                   </TD>
#                   <TD width="59%">
#                     <input name="B" type="submit" class="input1" value="查　　詢">
#                   </TD>
#                 </TR>
#               </TABLE>
#             </TD>
#           </TR>
#           <TR>
#             <TD width="355" align="center">廠商名稱</TD>
#             <TD width="197" align="center">聯絡電話</TD>
#             <TD width="211" align="center">核發案件編號</TD>
#           </TR>
#
#           <TR>
#             <TD>統一生機開發股份有限公司</TD>
#             <TD align="left">03-4340372</TD>
#             <TD align="center">
#               <a href="QueryApplyDetail?Case_NO=120221034002&Nnify_NO=16781797">AGGR-111-1034-002</A>
# 			</TD>
#           </TR>
#
#           <TR>
#             <TD>統一生機開發股份有限公司</TD>
#             <TD align="left">03-4340372</TD>
#             <TD align="center">
#               <a href="QueryApplyDetail?Case_NO=120221034008&Nnify_NO=16781797">AGGR-111-1034-008</A>
# 			</TD>
#           </TR>
#
#           <TR>
#             <TD>統一生機開發股份有限公司</TD>
#             <TD align="left">03-4340372</TD>
#             <TD align="center">
#               <a href="QueryApplyDetail?Case_NO=120221034009&Nnify_NO=16781797">AGGR-111-1034-009</A>
# 			</TD>
#           </TR>
#
#           <TR>
#             <TD>統一生機開發股份有限公司</TD>
#             <TD align="left">03-4340372</TD>
#             <TD align="center">
#               <a href="QueryApplyDetail?Case_NO=120221034018&Nnify_NO=16781797">AGGR-111-1034-018</A>
# 			</TD>
#           </TR>
#
#           <TR>
#             <TD>青荷國際有限公司</TD>
#             <TD align="left">03-3594557</TD>
#             <TD align="center">
#               <a href="QueryApplyDetail?Case_NO=120221067003&Nnify_NO=24407269">AGGR-111-1067-003</A>
# 			</TD>
#           </TR>
#
#           <TR>
#             <TD>青荷國際有限公司</TD>
#             <TD align="left">03-3594557</TD>
#             <TD align="center">
#               <a href="QueryApplyDetail?Case_NO=120221067006&Nnify_NO=24407269">AGGR-111-1067-006</A>
# 			</TD>
#           </TR>
#
#           <TR>
#             <TD>青荷國際有限公司</TD>
#             <TD align="left">03-3594557</TD>
#             <TD align="center">
#               <a href="QueryApplyDetail?Case_NO=120221067020&Nnify_NO=24407269">AGGR-111-1067-020</A>
# 			</TD>
#           </TR>
#
#           <TR>
#             <TD>青荷國際有限公司</TD>
#             <TD align="left">03-3594557</TD>
#             <TD align="center">
#               <a href="QueryApplyDetail?Case_NO=120221067021&Nnify_NO=24407269">AGGR-111-1067-021</A>
# 			</TD>
#           </TR>
#
#           <TR>
#             <TD>青荷國際有限公司</TD>
#             <TD align="left">03-3594557</TD>
#             <TD align="center">
#               <a href="QueryApplyDetail?Case_NO=120221067033&Nnify_NO=24407269">AGGR-111-1067-033</A>
# 			</TD>
#           </TR>
#
#           <TR>
#             <TD>綠動會股份有限公司</TD>
#             <TD align="left">04-25299885</TD>
#             <TD align="center">
#               <a href="QueryApplyDetail?Case_NO=220222003605&Nnify_NO=24430183">AGGR-111-2003-605</A>
# 			</TD>
#           </TR>
#
#           <TR>
#             <TD>新和食品股份有限公司</TD>
#             <TD align="left">02-25954321</TD>
#             <TD align="center">
#               <a href="QueryApplyDetail?Case_NO=120221649006&Nnify_NO=24956270">AGGR-111-1649-006</A>
# 			</TD>
#           </TR>
#
#           <TR>
#             <TD>綠昇貿易行銷有限公司</TD>
#             <TD align="left">04-26262377</TD>
#             <TD align="center">
#               <a href="QueryApplyDetail?Case_NO=220222004016&Nnify_NO=25054571">AGGR-111-2004-016</A>
# 			</TD>
#           </TR>
#
#           <TR>
#             <TD>日商沖繩伊藤園股份有限公司台灣分公司</TD>
#             <TD align="left">0225163123</TD>
#             <TD align="center">
#               <a href="QueryApplyDetail?Case_NO=1202211089001&Nnify_NO=53652917">AGGR-111-1A89-001</A>
# 			</TD>
#           </TR>
#
#           <TR>
#             <TD>智慧體股份有限公司</TD>
#             <TD align="left">27670988</TD>
#             <TD align="center">
#               <a href="QueryApplyDetail?Case_NO=120221311002&Nnify_NO=54150883">AGGR-111-1311-002</A>
# 			</TD>
#           </TR>
#
#           <TR>
#             <TD>智慧體股份有限公司</TD>
#             <TD align="left">27670988</TD>
#             <TD align="center">
#               <a href="QueryApplyDetail?Case_NO=120221311004&Nnify_NO=54150883">AGGR-111-1311-004</A>
# 			</TD>
#           </TR>
#
#           <TR>
#             <TD>日商夢多貿易股份有限公司台灣分公司</TD>
#             <TD align="left">0227200322</TD>
#             <TD align="center">
#               <a href="QueryApplyDetail?Case_NO=1202211040001&Nnify_NO=54952841">AGGR-111-1A40-001</A>
# 			</TD>
#           </TR>
#
#           <TR>
#             <TD>苗林食品有限公司</TD>
#             <TD align="left">02-2581-0034</TD>
#             <TD align="center">
#               <a href="QueryApplyDetail?Case_NO=120221046001&Nnify_NO=84754875">AGGR-111-1046-001</A>
# 			</TD>
#           </TR>
#
#           <TR>
#             <TD>好市多股份有限公司</TD>
#             <TD align="left">02-87919988</TD>
#             <TD align="center">
#               <a href="QueryApplyDetail?Case_NO=320223309002&Nnify_NO=96972798">AGGR-111-3309-002</A>
# 			</TD>
#           </TR>
#
#           <TR>
#             <TD>好市多股份有限公司</TD>
#             <TD align="left">02-87919988</TD>
#             <TD align="center">
#               <a href="QueryApplyDetail?Case_NO=320223309003&Nnify_NO=96972798">AGGR-111-3309-003</A>
# 			</TD>
#           </TR>
#
#           <TR>
#             <TD>好市多股份有限公司</TD>
#             <TD align="left">02-87919988</TD>
#             <TD align="center">
#               <a href="QueryApplyDetail?Case_NO=320223309010&Nnify_NO=96972798">AGGR-111-3309-010</A>
# 			</TD>
#           </TR>
#
#           <TR>
#             <TD>好市多股份有限公司</TD>
#             <TD align="left">02-87919988</TD>
#             <TD align="center">
#               <a href="QueryApplyDetail?Case_NO=320223309015&Nnify_NO=96972798">AGGR-111-3309-015</A>
# 			</TD>
#           </TR>
#
#           <TR>
#             <TD>好市多股份有限公司</TD>
#             <TD align="left">02-87919988</TD>
#             <TD align="center">
#               <a href="QueryApplyDetail?Case_NO=320223309052&Nnify_NO=96972798">AGGR-111-3309-052</A>
# 			</TD>
#           </TR>
#
#           <TR>
#             <TD>好市多股份有限公司</TD>
#             <TD align="left">02-87919988</TD>
#             <TD align="center">
#               <a href="QueryApplyDetail?Case_NO=320223309069&Nnify_NO=96972798">AGGR-111-3309-069</A>
# 			</TD>
#           </TR>
#
#           <TR>
#             <TD>好市多股份有限公司</TD>
#             <TD align="left">02-87919988</TD>
#             <TD align="center">
#               <a href="QueryApplyDetail?Case_NO=320223309070&Nnify_NO=96972798">AGGR-111-3309-070</A>
# 			</TD>
#           </TR>
#
#           <TR>
#             <TD>好市多股份有限公司</TD>
#             <TD align="left">02-87919988</TD>
#             <TD align="center">
#               <a href="QueryApplyDetail?Case_NO=320223309133&Nnify_NO=96972798">AGGR-111-3309-133</A>
# 			</TD>
#           </TR>
#
#         </TABLE></TD>
#     </TR>
#   </TABLE>
# </form>
# </body>
# </html>

# %%
for tr_obj in soup.select('table table tr')[7:]:
    com_name = tr_obj.select('td')[0].text
    tel_no = tr_obj.select('td')[1].text
    case_no = tr_obj.select('td')[2].text.replace("\n", "")
    print("Company Name:\t", com_name)
    print("Telephone No.:\t", tel_no)
    print("Case No.:\t", case_no)
    print("==========")
# Out:
# Company Name:	 統一生機開發股份有限公司
# Telephone No.:	 03-4340372
# Case No.:	 AGGR-111-1034-002
# ==========
# Company Name:	 統一生機開發股份有限公司
# Telephone No.:	 03-4340372
# Case No.:	 AGGR-111-1034-008
# ==========
# Company Name:	 統一生機開發股份有限公司
# Telephone No.:	 03-4340372
# Case No.:	 AGGR-111-1034-009
# ==========
# Company Name:	 統一生機開發股份有限公司
# Telephone No.:	 03-4340372
# Case No.:	 AGGR-111-1034-018
# ==========
# Company Name:	 青荷國際有限公司
# Telephone No.:	 03-3594557
# Case No.:	 AGGR-111-1067-003
# ==========
# Company Name:	 青荷國際有限公司
# Telephone No.:	 03-3594557
# Case No.:	 AGGR-111-1067-006
# ==========
# Company Name:	 青荷國際有限公司
# Telephone No.:	 03-3594557
# Case No.:	 AGGR-111-1067-020
# ==========
# Company Name:	 青荷國際有限公司
# Telephone No.:	 03-3594557
# Case No.:	 AGGR-111-1067-021
# ==========
# Company Name:	 青荷國際有限公司
# Telephone No.:	 03-3594557
# Case No.:	 AGGR-111-1067-033
# ==========
# Company Name:	 綠動會股份有限公司
# Telephone No.:	 04-25299885
# Case No.:	 AGGR-111-2003-605
# ==========
# Company Name:	 新和食品股份有限公司
# Telephone No.:	 02-25954321
# Case No.:	 AGGR-111-1649-006
# ==========
# Company Name:	 綠昇貿易行銷有限公司
# Telephone No.:	 04-26262377
# Case No.:	 AGGR-111-2004-016
# ==========
# Company Name:	 日商沖繩伊藤園股份有限公司台灣分公司
# Telephone No.:	 0225163123
# Case No.:	 AGGR-111-1A89-001
# ==========
# Company Name:	 智慧體股份有限公司
# Telephone No.:	 27670988
# Case No.:	 AGGR-111-1311-002
# ==========
# Company Name:	 智慧體股份有限公司
# Telephone No.:	 27670988
# Case No.:	 AGGR-111-1311-004
# ==========
# Company Name:	 日商夢多貿易股份有限公司台灣分公司
# Telephone No.:	 0227200322
# Case No.:	 AGGR-111-1A40-001
# ==========
# Company Name:	 苗林食品有限公司
# Telephone No.:	 02-2581-0034
# Case No.:	 AGGR-111-1046-001
# ==========
# Company Name:	 好市多股份有限公司
# Telephone No.:	 02-87919988
# Case No.:	 AGGR-111-3309-002
# ==========
# Company Name:	 好市多股份有限公司
# Telephone No.:	 02-87919988
# Case No.:	 AGGR-111-3309-003
# ==========
# Company Name:	 好市多股份有限公司
# Telephone No.:	 02-87919988
# Case No.:	 AGGR-111-3309-010
# ==========
# Company Name:	 好市多股份有限公司
# Telephone No.:	 02-87919988
# Case No.:	 AGGR-111-3309-015
# ==========
# Company Name:	 好市多股份有限公司
# Telephone No.:	 02-87919988
# Case No.:	 AGGR-111-3309-052
# ==========
# Company Name:	 好市多股份有限公司
# Telephone No.:	 02-87919988
# Case No.:	 AGGR-111-3309-069
# ==========
# Company Name:	 好市多股份有限公司
# Telephone No.:	 02-87919988
# Case No.:	 AGGR-111-3309-070
# ==========
# Company Name:	 好市多股份有限公司
# Telephone No.:	 02-87919988
# Case No.:	 AGGR-111-3309-133
# ==========
