# %%
"""https://www.twse.com.tw/zh/trading/historical/mi-index.html"""
from io import StringIO

import pandas as pd
import requests
# from bs4 import BeautifulSoup

# %%
res = requests.get(
    "https://www.twse.com.tw/rwd/zh/afterTrading/MI_INDEX?response=html",
    headers={
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/135.0.0.0 Safari/537.36",
    }
)

# %%
# soup = BeautifulSoup(res.text, "html.parser")
# print(soup.prettify())

# %%
# table_tag_list = soup.select("table")
# table_tag_list.__len__()

# %%
# df_list = []
# for table_tag in table_tag_list:
#     df = pd.read_html(StringIO(str(table_tag)))
#     df_list.extend(df)

# 不需要 BeautifulSoup
# 直接把 requsts 的 text 轉成 StringIO
# 就可以用 pd.read_html 讀取了
df_list = pd.read_html(StringIO(res.text))

# %%
print(type(df_list[0]))
print(df_list[0])
print("-----------------")
print(df_list[1])
# Out:
# <class 'pandas.core.frame.DataFrame'>
#    114年04月21日 大盤統計資訊
#                 成交統計       成交金額(元)     成交股數(股)     成交筆數
# 0             1.一般股票  188334112225  2358582720  1635475
# 1           2.台灣存託憑證     111223669    19193975     4703
# 2             3.受益憑證             0           0        0
# 3              4.ETF   24133447675  1057790390   437763
# 4             5.受益證券       1954549      158002       62
# 5           6.變更交易股票      15800254     1729884     2376
# 6          7.認購(售)權證     954919510  1048044000    35354
# 7            8.轉換公司債             0           0        0
# 8          9.附認股權特別股             0           0        0
# 9         10.附認股權公司債             0           0        0
# 10          11.認股權憑證             0           0        0
# 11            12.公司債             0           0        0
# 12            13.ETN       2185610      289000       78
# 13          14.創新板股票      92607450     1160853     1159
# 14   15.創新板-變更交易方法股票             0           0        0
# ...

# %%
print(df_list[0].columns)
print("-----------------")
print(df_list[1].columns)
# Out:
# MultiIndex([('114年04月21日 大盤統計資訊',    '成交統計'),
#             ('114年04月21日 大盤統計資訊', '成交金額(元)'),
#             ('114年04月21日 大盤統計資訊', '成交股數(股)'),
#             ('114年04月21日 大盤統計資訊',    '成交筆數')],
#            )
# -----------------
# MultiIndex([('漲跌證券數合計',   '類型'),
#             ('漲跌證券數合計', '整體市場'),
#             ('漲跌證券數合計',   '股票')],
#            )

# %%
df_list[0].loc[:, ('114年04月21日 大盤統計資訊')]
# Out:
#                成交統計       成交金額(元)     成交股數(股)     成交筆數
# 0            1.一般股票  188334112225  2358582720  1635475
# 1          2.台灣存託憑證     111223669    19193975     4703
# 2            3.受益憑證             0           0        0
# 3             4.ETF   24133447675  1057790390   437763
# 4            5.受益證券       1954549      158002       62
# 5          6.變更交易股票      15800254     1729884     2376
# 6         7.認購(售)權證     954919510  1048044000    35354
# 7           8.轉換公司債             0           0        0
# 8         9.附認股權特別股             0           0        0
# 9        10.附認股權公司債             0           0        0
# 10         11.認股權憑證             0           0        0
# 11           12.公司債             0           0        0
# 12           13.ETN       2185610      289000       78
# 13         14.創新板股票      92607450     1160853     1159
# 14  15.創新板-變更交易方法股票             0           0        0
# 15  證券合計(1+6+14+15)  188442519929  2361473457  1639010
# ...

# %%
df_list[1].loc[:, ('漲跌證券數合計')]
# Out:
#        類型        整體市場      股票
# 0  上漲(漲停)   1,595(10)  109(4)
# 1  下跌(跌停)  4,821(107)  893(6)
# 2      持平         278      30
# 3     未成交       25779       4
# 4     無比價        2572       2

# %%
df_list[1].get(('漲跌證券數合計'))
# Out:
#        類型        整體市場      股票
# 0  上漲(漲停)   1,595(10)  109(4)
# 1  下跌(跌停)  4,821(107)  893(6)
# 2      持平         278      30
# 3     未成交       25779       4
# 4     無比價        2572       2

# %%
df_list[1]["漲跌證券數合計"]
# Out:
#        類型        整體市場      股票
# 0  上漲(漲停)   1,595(10)  109(4)
# 1  下跌(跌停)  4,821(107)  893(6)
# 2      持平         278      30
# 3     未成交       25779       4
# 4     無比價        2572       2

# %%
df_list[1]["漲跌證券數合計"]["類型"]
